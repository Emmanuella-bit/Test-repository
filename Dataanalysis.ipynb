# %%
""""create a dictionary of your own data and convert it to a dataframe
do some basic exploratory analysis on the data"""
# Out:
# '"create a dictionary of your own data and convert it to a dataframe\ndo some basic exploratory analysis on the data'

# %%
import pandas as pd
data = {"Housing_type": ["Single_room", "apartment","studio", "Bangalow"],
              "Number_of_rooms": ["1", "2", "1", "3"],
              "Housing_condition": ["good_condition", "fully_furnished", "small", "poor_condition"],
              "Location": ["Augsburg", "Landshut", "München", "Passau"],
              }

# %%
dt = pd.DataFrame(data)

# %%
print (dt)
# Out:
#   Housing_type Number_of_rooms Housing_condition  Location
# 0  Single_room               1    good_condition  Augsburg
# 1    apartment               2   fully_furnished  Landshut
# 2       studio               1             small   München
# 3     Bangalow               3    poor_condition    Passau

# %%
print(dt.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Housing_type       4 non-null      object
#  1   Number_of_rooms    4 non-null      object
#  2   Housing_condition  4 non-null      object
#  3   Location           4 non-null      object
# dtypes: object(4)
# memory usage: 256.0+ bytes
# None

# %%
print(dt.describe())
# Out:
#        Housing_type Number_of_rooms Housing_condition  Location
# count             4               4                 4         4
# unique            4               3                 4         4
# top     Single_room               1    good_condition  Augsburg
# freq              1               2                 1         1

# %%
import pandas as pd

data = {
    'Product': ['Apple', 'Banana', 'Orange', 'Grapes'],
    'Price': [120, 40, 60, 150],
    'Quantity': [10, 20, 15, 5]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Product  Price  Quantity
# 0   Apple    120        10
# 1  Banana     40        20
# 2  Orange     60        15
# 3  Grapes    150         5

# %%
print(df.describe())
# Out:
#             Price   Quantity
# count    4.000000   4.000000
# mean    92.500000  12.500000
# std     51.234754   6.454972
# min     40.000000   5.000000
# 25%     55.000000   8.750000
# 50%     90.000000  12.500000
# 75%    127.500000  16.250000
# max    150.000000  20.000000

# %%
print(dt.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Housing_type       4 non-null      object
#  1   Number_of_rooms    4 non-null      object
#  2   Housing_condition  4 non-null      object
#  3   Location           4 non-null      object
# dtypes: object(4)
# memory usage: 256.0+ bytes
# None

# %%
# Introduction to data cleaning
#1 subset columns and rows
# basic pandas data manpuli
#selecting specific data  points based on conditions

# %%
import pandas as pd

# %%
datapath = "/root/ds_tutorial/Test-repository/WhatsgoodlyData-6.csv"

data = pd.read_csv(datapath)

# %%
data
# Out:
#                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1     What social platform has influenced your onlin...       Mobile
# 2     What social platform has influenced your onlin...       Mobile
# 3     What social platform has influenced your onlin...       Mobile
# 4     What social platform has influenced your onlin...       Mobile
# ...                                                 ...          ...
# 1445  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
# 1447  What social platform has influenced your onlin...       Custom
# 1448  What social platform has influenced your onlin...       Custom
# 1449  What social platform has influenced your onlin...       Custom
#
#                Segment Description     Answer  Count  Percentage
# 0                   Global results   Facebook    548       0.205
# ...

# %%
data.head(10)
# Out:
#                                             Question Segment Type  \
# 0  What social platform has influenced your onlin...       Mobile
# 1  What social platform has influenced your onlin...       Mobile
# 2  What social platform has influenced your onlin...       Mobile
# 3  What social platform has influenced your onlin...       Mobile
# 4  What social platform has influenced your onlin...       Mobile
# 5  What social platform has influenced your onlin...          Web
# 6  What social platform has influenced your onlin...          Web
# 7  What social platform has influenced your onlin...          Web
# 8  What social platform has influenced your onlin...          Web
# 9  What social platform has influenced your onlin...          Web
#
#   Segment Description     Answer  Count  Percentage
# 0      Global results   Facebook    548       0.205
# 1      Global results  Instagram    916       0.342
# 2      Global results   Snapchat     86       0.032
# ...

# %%
data.tail()
# Out:
#                                                Question Segment Type  \
# 1445  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
# 1447  What social platform has influenced your onlin...       Custom
# 1448  What social platform has influenced your onlin...       Custom
# 1449  What social platform has influenced your onlin...       Custom
#
#                Segment Description     Answer  Count  Percentage
# 1445  Sexual orientation? Straight   Facebook    215       0.180
# 1446  Sexual orientation? Straight  Instagram    354       0.297
# 1447  Sexual orientation? Straight   Snapchat     44       0.037
# 1448  Sexual orientation? Straight    Twitter     88       0.074
# 1449  Sexual orientation? Straight        NaN    492       0.412

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Question             1450 non-null   object
#  1   Segment Type         1450 non-null   object
#  2   Segment Description  1450 non-null   object
#  3   Answer               1160 non-null   object
#  4   Count                1450 non-null   int64
#  5   Percentage           1450 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 68.1+ KB

# %%
data.dtypes
# Out:
# Question                object
# Segment Type            object
# Segment Description     object
# Answer                  object
# Count                    int64
# Percentage             float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Question', 'Segment Type', 'Segment Description', 'Answer', 'Count',
#        'Percentage'],
#       dtype='object')

# %%
type(data["Answer"]) #data series
# Out:
# pandas.core.series.Series

# %%
data[["Answer"]] #dataframe
# Out:
#          Answer
# 0      Facebook
# 1     Instagram
# 2      Snapchat
# 3       Twitter
# 4           NaN
# ...         ...
# 1445   Facebook
# 1446  Instagram
# 1447   Snapchat
# 1448    Twitter
# 1449        NaN
#
# [1450 rows x 1 columns]

# %%
data[["Answer"]].columns
# Out:
# Index(['Answer'], dtype='object')

# %%
data.Answer
# Out:
# 0        Facebook
# 1       Instagram
# 2        Snapchat
# 3         Twitter
# 4             NaN
#           ...
# 1445     Facebook
# 1446    Instagram
# 1447     Snapchat
# 1448      Twitter
# 1449          NaN
# Name: Answer, Length: 1450, dtype: object

# %%
# Row subsetting
# loc or iloc
#loc-- takes starting index and stop index /lower index/limit to upper index 
#iloc-- takes the positions of the row-- start/lower limit to upper limit but the upper position is not included in subsetting the rows

# %%
data.loc[10:25]
# Out:
#                                              Question Segment Type  \
# 10  What social platform has influenced your onlin...       Gender
# 11  What social platform has influenced your onlin...       Gender
# 12  What social platform has influenced your onlin...       Gender
# 13  What social platform has influenced your onlin...       Gender
# 14  What social platform has influenced your onlin...       Gender
# 15  What social platform has influenced your onlin...       Gender
# 16  What social platform has influenced your onlin...       Gender
# 17  What social platform has influenced your onlin...       Gender
# 18  What social platform has influenced your onlin...       Gender
# 19  What social platform has influenced your onlin...       Gender
# 20  What social platform has influenced your onlin...   University
# 21  What social platform has influenced your onlin...   University
# 22  What social platform has influenced your onlin...   University
# ...

# %%
data.iloc[10:25]
# Out:
#                                              Question Segment Type  \
# 10  What social platform has influenced your onlin...       Gender
# 11  What social platform has influenced your onlin...       Gender
# 12  What social platform has influenced your onlin...       Gender
# 13  What social platform has influenced your onlin...       Gender
# 14  What social platform has influenced your onlin...       Gender
# 15  What social platform has influenced your onlin...       Gender
# 16  What social platform has influenced your onlin...       Gender
# 17  What social platform has influenced your onlin...       Gender
# 18  What social platform has influenced your onlin...       Gender
# 19  What social platform has influenced your onlin...       Gender
# 20  What social platform has influenced your onlin...   University
# 21  What social platform has influenced your onlin...   University
# 22  What social platform has influenced your onlin...   University
# ...

# %%
data.iloc[:,1:]
# Out:
#      Segment Type           Segment Description     Answer  Count  Percentage
# 0          Mobile                Global results   Facebook    548       0.205
# 1          Mobile                Global results  Instagram    916       0.342
# 2          Mobile                Global results   Snapchat     86       0.032
# 3          Mobile                Global results    Twitter    179       0.067
# 4          Mobile                Global results        NaN    947       0.354
# ...           ...                           ...        ...    ...         ...
# 1445       Custom  Sexual orientation? Straight   Facebook    215       0.180
# 1446       Custom  Sexual orientation? Straight  Instagram    354       0.297
# 1447       Custom  Sexual orientation? Straight   Snapchat     44       0.037
# 1448       Custom  Sexual orientation? Straight    Twitter     88       0.074
# 1449       Custom  Sexual orientation? Straight        NaN    492       0.412
#
# [1450 rows x 5 columns]

# %%
data.iloc[25:51, 1:3]
# Out:
#    Segment Type             Segment Description
# 25   University      University of Pennsylvania
# 26   University      University of Pennsylvania
# 27   University      University of Pennsylvania
# 28   University      University of Pennsylvania
# 29   University      University of Pennsylvania
# 30   University            Students of New York
# 31   University            Students of New York
# 32   University            Students of New York
# 33   University            Students of New York
# 34   University            Students of New York
# 35   University  University of Central Arkansas
# 36   University  University of Central Arkansas
# 37   University  University of Central Arkansas
# 38   University  University of Central Arkansas
# 39   University  University of Central Arkansas
# 40   University         Northeastern University
# 41   University         Northeastern University
# 42   University         Northeastern University
# 43   University         Northeastern University
# ...

# %%
#Import the data and show the first and last 10 data samples
# select the first and last data columns
# Select 100th data sample to 200th data sample
# Perform basic statistics on the result of 3

# %%
#shape
data.shape
# Out:
# (1450, 6)

# %%
#data[condition]
data[data["Answer"]=="Facebook"]
# Out:
#                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 5     What social platform has influenced your onlin...          Web
# 10    What social platform has influenced your onlin...       Gender
# 15    What social platform has influenced your onlin...       Gender
# 20    What social platform has influenced your onlin...   University
# ...                                                 ...          ...
# 1425  What social platform has influenced your onlin...       Custom
# 1430  What social platform has influenced your onlin...       Custom
# 1435  What social platform has influenced your onlin...       Custom
# 1440  What social platform has influenced your onlin...       Custom
# 1445  What social platform has influenced your onlin...       Custom
#
#                Segment Description    Answer  Count  Percentage
# 0                   Global results  Facebook    548       0.205
# ...

# %%
#mutiple conditions
data[(data["Answer"]=="Facebook") & (data["Percentage"]>0.3)]
# Out:
#                                                Question Segment Type  \
# 20    What social platform has influenced your onlin...   University
# 40    What social platform has influenced your onlin...   University
# 50    What social platform has influenced your onlin...   University
# 55    What social platform has influenced your onlin...   University
# 100   What social platform has influenced your onlin...   University
# 120   What social platform has influenced your onlin...   University
# 150   What social platform has influenced your onlin...   University
# 165   What social platform has influenced your onlin...   University
# 180   What social platform has influenced your onlin...   University
# 195   What social platform has influenced your onlin...   University
# 210   What social platform has influenced your onlin...   University
# 225   What social platform has influenced your onlin...   University
# 230   What social platform has influenced your onlin...   University
# ...

# %%
data[(data["Answer"]=="Facebook") | (data["Percentage"]>0.3)]
# Out:
#                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1     What social platform has influenced your onlin...       Mobile
# 4     What social platform has influenced your onlin...       Mobile
# 5     What social platform has influenced your onlin...          Web
# 9     What social platform has influenced your onlin...          Web
# ...                                                 ...          ...
# 1440  What social platform has influenced your onlin...       Custom
# 1441  What social platform has influenced your onlin...       Custom
# 1444  What social platform has influenced your onlin...       Custom
# 1445  What social platform has influenced your onlin...       Custom
# 1449  What social platform has influenced your onlin...       Custom
#
#                Segment Description     Answer  Count  Percentage
# 0                   Global results   Facebook    548       0.205
# ...

# %%
data[(data["Segment Type"]=="Mobile") & (data["Count"]>500)]
# Out:
#                                             Question Segment Type  \
# 0  What social platform has influenced your onlin...       Mobile
# 1  What social platform has influenced your onlin...       Mobile
# 4  What social platform has influenced your onlin...       Mobile
#
#   Segment Description     Answer  Count  Percentage
# 0      Global results   Facebook    548       0.205
# 1      Global results  Instagram    916       0.342
# 4      Global results        NaN    947       0.354

# %%
data[(data["Segment Type"]=="Web") | (data["Answer"]=="Instagram")]
# Out:
#                                                Question Segment Type  \
# 1     What social platform has influenced your onlin...       Mobile
# 5     What social platform has influenced your onlin...          Web
# 6     What social platform has influenced your onlin...          Web
# 7     What social platform has influenced your onlin...          Web
# 8     What social platform has influenced your onlin...          Web
# ...                                                 ...          ...
# 1426  What social platform has influenced your onlin...       Custom
# 1431  What social platform has influenced your onlin...       Custom
# 1436  What social platform has influenced your onlin...       Custom
# 1441  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
#
#                Segment Description     Answer  Count  Percentage
# 1                   Global results  Instagram    916       0.342
# ...

# %%
#sorting
#sort by  is a sequence means its a list
data.sort_values(by=["Answer"])#automatically is in ascending order
# Out:
#                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1030  What social platform has influenced your onlin...       Custom
# 315   What social platform has influenced your onlin...   University
# 625   What social platform has influenced your onlin...   University
# 310   What social platform has influenced your onlin...   University
# ...                                                 ...          ...
# 1429  What social platform has influenced your onlin...       Custom
# 1434  What social platform has influenced your onlin...       Custom
# 1439  What social platform has influenced your onlin...       Custom
# 1444  What social platform has influenced your onlin...       Custom
# 1449  What social platform has influenced your onlin...       Custom
#
#                         Segment Description    Answer  Count  Percentage
# ...

# %%
#For descending   ,ascending= False
data.sort_values(by=["Answer"], ascending=False)
# Out:
#                                                Question Segment Type  \
# 1448  What social platform has influenced your onlin...       Custom
# 553   What social platform has influenced your onlin...   University
# 1298  What social platform has influenced your onlin...       Custom
# 598   What social platform has influenced your onlin...   University
# 593   What social platform has influenced your onlin...   University
# ...                                                 ...          ...
# 1429  What social platform has influenced your onlin...       Custom
# 1434  What social platform has influenced your onlin...       Custom
# 1439  What social platform has influenced your onlin...       Custom
# 1444  What social platform has influenced your onlin...       Custom
# 1449  What social platform has influenced your onlin...       Custom
#
#                   Segment Description   Answer  Count  Percentage
# 1448     Sexual orientation? Straight  Twitter     88       0.074
# ...

# %%
#For sorting multiply colums
data.sort_values(by=["Answer", "Count"], ascending=False)
# Out:
#                                                Question Segment Type  \
# 3     What social platform has influenced your onlin...       Mobile
# 1388  What social platform has influenced your onlin...       Custom
# 18    What social platform has influenced your onlin...       Gender
# 1028  What social platform has influenced your onlin...       Custom
# 1338  What social platform has influenced your onlin...       Custom
# ...                                                 ...          ...
# 869   What social platform has influenced your onlin...   University
# 874   What social platform has influenced your onlin...   University
# 889   What social platform has influenced your onlin...   University
# 989   What social platform has influenced your onlin...       Custom
# 994   What social platform has influenced your onlin...       Custom
#
#              Segment Description   Answer  Count  Percentage
# 3                 Global results  Twitter    179       0.067
# ...

# %%
#get number of missing values
data.isnull().sum()
# Out:
# Question                 0
# Segment Type             0
# Segment Description      0
# Answer                 290
# Count                    0
# Percentage               0
# dtype: int64

# %%
data_rm = data.dropna()

# %%
data_rm
# Out:
#                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1     What social platform has influenced your onlin...       Mobile
# 2     What social platform has influenced your onlin...       Mobile
# 3     What social platform has influenced your onlin...       Mobile
# 5     What social platform has influenced your onlin...          Web
# ...                                                 ...          ...
# 1443  What social platform has influenced your onlin...       Custom
# 1445  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
# 1447  What social platform has influenced your onlin...       Custom
# 1448  What social platform has influenced your onlin...       Custom
#
#                Segment Description     Answer  Count  Percentage
# 0                   Global results   Facebook    548       0.205
# ...

# %%
#In place 
data.dropna(inplace=True)

# %%
data
# Out:
#                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1     What social platform has influenced your onlin...       Mobile
# 2     What social platform has influenced your onlin...       Mobile
# 3     What social platform has influenced your onlin...       Mobile
# 5     What social platform has influenced your onlin...          Web
# ...                                                 ...          ...
# 1443  What social platform has influenced your onlin...       Custom
# 1445  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
# 1447  What social platform has influenced your onlin...       Custom
# 1448  What social platform has influenced your onlin...       Custom
#
#                Segment Description     Answer  Count  Percentage
# 0                   Global results   Facebook    548       0.205
# ...

# %%
#knowing the value count
data.value_counts()
# Out:
# Question                                                        Segment Type  Segment Description         Answer     Count  Percentage
# What social platform has influenced your online shopping most?  Web           Web                         Twitter    0      0.000         1
#                                                                 Custom        Are you a? SVB team member  Facebook   0      0.000         1
#                                                                                                           Instagram  0      0.000         1
#                                                                                                           Snapchat   0      0.000         1
#                                                                                                           Twitter    0      0.000         1
#                                                                                                                                          ..
# ...

# %%
data[["Answer"]].value_counts()
# Out:
# Answer
# Facebook     290
# Instagram    290
# Snapchat     290
# Twitter      290
# Name: count, dtype: int64

# %%
data[["Segment Type"]].value_counts()
# Out:
# Segment Type
# University      696
# Custom          448
# Gender            8
# Mobile            4
# Web               4
# Name: count, dtype: int64

# %%
data["Answer"].unique()
# Out:
# array(['Facebook', 'Instagram', 'Snapchat', 'Twitter'], dtype=object)

# %%
#Finding number of unique values
data["Answer"].nunique()
# Out:
# 4

# %%
#find the number of segment descriptions
#find the types of segment description 
#For each segment decription value find the number of times they occur

# %%
#1
data["Segment Description"].nunique()
# Out:
# 289

# %%
#2
data["Segment Description"].unique()
# Out:
# array(['Global results', 'Web', 'Female voters', 'Male voters',
#        'University of Delaware', 'University of Pennsylvania',
#        'Students of New York', 'University of Central Arkansas',
#        'Northeastern University', 'West Virginia University ',
#        'Northern Arizona University',
#        'University of California, Santa Barbara', 'University of Memphis',
#        'Auburn University', 'Randolph-Macon College', 'Wisconsin HS',
#        'Penn State University', 'Case Western Reserve University',
#        'Rutgers University', 'University of Oregon',
#        'University of Toronto', 'State University of New York Geneso',
#        'Carthage College', 'University of South Carolina',
#        'Wesleyan University', 'Memorial University of Newfoundland',
#        'University of Kansas', 'University of Redlands',
#        'University of Arkansas', 'Richland High School',
#        'Wake Forest University', 'Iowa State University',
# ...

# %%
data[["Segment Description"]].value_counts()
# Out:
# Segment Description
# What's your major? Other       8
# West Virginia University       4
# Wesleyan University            4
# Wellesley College              4
# Web                            4
#                               ..
# Ohio State University          4
# Northwestern University        4
# Northern Arizona University    4
# Northeastern University        4
# Queens University              4
# Name: count, Length: 289, dtype: int64

# %%
data["count_discount"] = data["Count"] * data ["Percentage"]

# %%
data
# Out:
#                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1     What social platform has influenced your onlin...       Mobile
# 2     What social platform has influenced your onlin...       Mobile
# 3     What social platform has influenced your onlin...       Mobile
# 5     What social platform has influenced your onlin...          Web
# ...                                                 ...          ...
# 1443  What social platform has influenced your onlin...       Custom
# 1445  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
# 1447  What social platform has influenced your onlin...       Custom
# 1448  What social platform has influenced your onlin...       Custom
#
#                Segment Description     Answer  Count  Percentage  \
# 0                   Global results   Facebook    548       0.205
# ...

# %%
data["count_discount"] = data["Count"] -100 #data ["Percentage"]

# %%
import numpy as np

# %%
data["count_degree"] = np.where(data["Count"]>500, "high count", "low count")

# %%
data
# Out:
#                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1     What social platform has influenced your onlin...       Mobile
# 2     What social platform has influenced your onlin...       Mobile
# 3     What social platform has influenced your onlin...       Mobile
# 5     What social platform has influenced your onlin...          Web
# ...                                                 ...          ...
# 1443  What social platform has influenced your onlin...       Custom
# 1445  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
# 1447  What social platform has influenced your onlin...       Custom
# 1448  What social platform has influenced your onlin...       Custom
#
#                Segment Description     Answer  Count  Percentage  \
# 0                   Global results   Facebook    548       0.205
# ...

# %%
# when to save the orignal copy from the edited data
data_used = data.copy()

# %%
#combine both columns
data_used["segment_and_answer"] = data_used["Segment Type"]

# %%
data_used.nsmallest(10, columns="Count")
# Out:
#                                              Question Segment Type  \
# 5   What social platform has influenced your onlin...          Web
# 6   What social platform has influenced your onlin...          Web
# 7   What social platform has influenced your onlin...          Web
# 8   What social platform has influenced your onlin...          Web
# 22  What social platform has influenced your onlin...   University
# 23  What social platform has influenced your onlin...   University
# 27  What social platform has influenced your onlin...   University
# 28  What social platform has influenced your onlin...   University
# 30  What social platform has influenced your onlin...   University
# 35  What social platform has influenced your onlin...   University
#
#                Segment Description     Answer  Count  Percentage  \
# 5                              Web   Facebook      0         0.0
# 6                              Web  Instagram      0         0.0
# ...

# %%
data_used.nlargest(5, columns="Count")
# Out:
#                                                Question Segment Type  \
# 1     What social platform has influenced your onlin...       Mobile
# 1386  What social platform has influenced your onlin...       Custom
# 1026  What social platform has influenced your onlin...       Custom
# 0     What social platform has influenced your onlin...       Mobile
# 1231  What social platform has influenced your onlin...       Custom
#
#      Segment Description     Answer  Count  Percentage  count_discount  \
# 1         Global results  Instagram    916       0.342             816
# 1386     I'm in? College  Instagram    781       0.336             681
# 1026    you a virgin? No  Instagram    579       0.341             479
# 0         Global results   Facebook    548       0.205             448
# 1231    Mac or PC? Mac 🖥  Instagram    546       0.375             446
#
#      count_degree segment_and_answer
# 1      high count             Mobile
# 1386   high count             Custom
# ...

# %%
data_used["Count"].mean()
# Out:
# np.float64(27.443103448275863)

# %%
data_used["Segment Type"].count()
# Out:
# np.int64(1160)

# %%
data_used["Segment Type"].value_counts()
# Out:
# Segment Type
# University    696
# Custom        448
# Gender          8
# Mobile          4
# Web             4
# Name: count, dtype: int64

# %%
data_used["Count"].sum()
# Out:
# np.int64(31834)

# %%
for rowindex, col in data_used.iterrows():
    print(col["Count"])
    if rowindex == 5:
        break
# Out:
# 548
# 916
# 86
# 179
# 0

# %%
data_used
# Out:
#                                                Question Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1     What social platform has influenced your onlin...       Mobile
# 2     What social platform has influenced your onlin...       Mobile
# 3     What social platform has influenced your onlin...       Mobile
# 5     What social platform has influenced your onlin...          Web
# ...                                                 ...          ...
# 1443  What social platform has influenced your onlin...       Custom
# 1445  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
# 1447  What social platform has influenced your onlin...       Custom
# 1448  What social platform has influenced your onlin...       Custom
#
#                Segment Description     Answer  Count  Percentage  \
# 0                   Global results   Facebook    548       0.205
# ...

# %%
data_used.rename(columns={"Question": "Inquiry", "Answer": "Response"})
# Out:
#                                                 Inquiry Segment Type  \
# 0     What social platform has influenced your onlin...       Mobile
# 1     What social platform has influenced your onlin...       Mobile
# 2     What social platform has influenced your onlin...       Mobile
# 3     What social platform has influenced your onlin...       Mobile
# 5     What social platform has influenced your onlin...          Web
# ...                                                 ...          ...
# 1443  What social platform has influenced your onlin...       Custom
# 1445  What social platform has influenced your onlin...       Custom
# 1446  What social platform has influenced your onlin...       Custom
# 1447  What social platform has influenced your onlin...       Custom
# 1448  What social platform has influenced your onlin...       Custom
#
#                Segment Description   Response  Count  Percentage  \
# 0                   Global results   Facebook    548       0.205
# ...
